# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanTuran/AI-for-Data-Extraction-Figures-Supplemental/blob/Computer-Vision-Paper/Replotted_Graphs_for_Paper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # --- Global Plot Template ---
import matplotlib.pyplot as plt
import seaborn as sns

# Apply seaborn style
sns.set_theme(style="whitegrid")

# Global figure style settings
def set_pub_style():
    plt.rcParams.update({
        "figure.figsize": (3.5, 3.5),   # single-column size (inches)
        "font.size": 11,                # main font size
        "axes.titlesize": 11,
        "axes.labelsize": 11,
        "xtick.labelsize": 10,
        "ytick.labelsize": 10,
        "legend.fontsize": 10,
        "lines.linewidth": 1.5,
        "lines.markersize": 6,
        "savefig.dpi": 600,
        "savefig.format": "pdf"
    })
    # Use rocket palette
    sns.set_palette("mako")

set_pub_style()

# %%
from matplotlib import rcParams
from matplotlib.font_manager import FontProperties

# Full, self-contained plot for Manual vs ChatGPT vs Perplexity
# Theme: seaborn "mako" (no external files needed)

import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import seaborn as sns

# ---- Data (every value from the spreadsheet) ----
manual_x = [
    526.18549920, 526.37421780, 526.56293630, 526.75165490, 526.94037350, 527.12909200, 527.31781060, 527.50652920,
    527.69524780, 527.88396630, 528.07268490, 528.26140347, 528.45012205, 528.63884062, 528.82755919, 529.01627780,
    529.20499630, 529.39371490, 529.58243350, 529.77115200, 529.95987060, 530.10140960, 530.19576880, 530.27440160,
    530.33730780, 530.40021400, 530.46312010, 530.52602630, 530.58893250, 530.64659650, 530.68329180, 530.71474490,
    530.74619800, 530.77765110, 530.80910420, 530.84055730, 530.87201040, 530.90346350, 530.93491660, 530.96636970,
    530.99782280, 531.02927590, 531.06072900, 531.09218210, 531.12363510, 531.15508820, 531.18654130, 531.21799440,
    531.24944750, 531.28090060, 531.31235370, 531.34904900, 531.40671300, 531.43816610, 531.46961920, 531.50107230,
    531.53252540, 531.56397850, 531.62688470, 531.75584240, 531.79987670, 531.90996250, 531.97286870, 532.02004840,
    532.05150150, 532.09868110, 532.15634510, 532.19304040, 532.22449350, 532.25070440, 532.27167310, 532.30312620,
    532.33457930, 532.36603240, 532.38175900, 532.41321210, 532.44466520, 532.47611820, 532.50757130, 532.52329790,
    532.55475100, 532.58620410, 532.61765720, 532.64911030, 532.68056340, 532.71201650, 532.72774300, 532.75919610,
    532.79064920, 532.82210230, 532.86928190, 532.90073500, 532.93218810, 532.97412560, 533.04227400, 533.10518020,
    533.16808630, 533.24671910, 533.34107840, 533.43543770, 533.54552350, 533.70278900, 533.89150750, 534.08022610,
    534.26894470, 534.45766330, 534.64638180, 534.83510040, 535.02381900, 535.21253750, 535.40125610, 535.58997470,
    535.77869330, 535.96741180, 536.15613040, 536.34484900, 536.53356750, 536.72228610, 536.91100470, 537.09972330,
    537.28844180, 537.47716040, 537.66587900, 537.85459760, 538.04331610, 538.23203470, 538.42075330, 538.60947180,
    538.79819040, 538.98690900, 539.17562760, 539.30143990
]
manual_y = [
    2674.59861700, 2721.60485500, 2733.35641400, 2780.36265200, 2792.11421100, 2792.11421100, 2815.61733000,
    2768.61109200, 2756.85953300, 2792.11421100, 2815.61733000, 2815.61733000, 2862.62356700, 2909.62980500,
# ---- Plot ----
sns.set_theme(style="whitegrid")
palette = sns.color_palette("mako", 3)

fig, ax = plt.subplots(figsize=(9, 6))

# --- Ensure x and y lengths match ---
min_len_manual = min(len(manual_x), len(manual_y))
manual_x = manual_x[:min_len_manual]
manual_y = manual_y[:min_len_manual]

min_len_chatgpt = min(len(chatgpt_x), len(chatgpt_y))
chatgpt_x = chatgpt_x[:min_len_chatgpt]
chatgpt_y = chatgpt_y[:min_len_chatgpt]

min_len_perplexity = min(len(perplexity_x), len(perplexity_y))
perplexity_x = perplexity_x[:min_len_perplexity]
perplexity_y = perplexity_y[:min_len_perplexity]


# Lines for each series (consistent 'mako' look)
# Scatter points for each series
ax.scatter(manual_x, manual_y, label="Manual (Original)", color=palette[2], s=40, alpha=0.8, edgecolor="black")
ax.scatter(chatgpt_x, chatgpt_y, label="ChatGPT", color=palette[1], s=40, alpha=0.8, edgecolor="black")
ax.scatter(perplexity_x, perplexity_y, label="Perplexity", color=palette[0], s=40, alpha=0.8, edgecolor="black")

# Optional: overlay faint lines connecting points
ax.plot(manual_x, manual_y, color=palette[2], linewidth=1.5, alpha=0.5)
ax.plot(chatgpt_x, chatgpt_y, color=palette[1], linewidth=1.5, alpha=0.5)
ax.plot(perplexity_x, perplexity_y, color=palette[0], linewidth=1.5, alpha=0.5)

ax.set_xlabel("Binding Energy (eV)", fontsize=20)  # increase number as desired
ax.set_ylabel("Counts (s)", fontsize=20)
ax.tick_params(axis='both', labelsize=20)  # match fontsize of axis labels


# Create a FontProperties object for the legend
legend_font = FontProperties(size=14.6)

# When adding the legend:
ax.legend(frameon=True, prop=legend_font)


ax.grid(True, which="major", linewidth=0.8, alpha=0.35)
ax.grid(True, which="minor", linewidth=0.5, alpha=0.20)

from matplotlib.ticker import AutoMinorLocator

# Make grid squares bigger
ax.xaxis.set_minor_locator(AutoMinorLocator(1))  # fewer minor ticks → bigger squares
ax.yaxis.set_minor_locator(AutoMinorLocator(1))


# Optional: manually set major ticks for more control over spacing
# ax.set_xticks(range(xmin, xmax+1, step))
# ax.set_yticks(range(ymin, ymax+1, step))



plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Synthetic data
np.random.seed(0)
observed = np.random.uniform(-2.5, 0, 147)
predicted = observed + np.random.normal(0, 0.3, 147)

set_pub_style()
fig, ax = plt.subplots()

# Use seaborn mako colormap
cmap = sns.color_palette("mako", as_cmap=True)

# Scatter points with mako colormap
palette = sns.color_palette("mako", 3)
point_color = palette[1]  # pick whichever shade you like

sc = ax.scatter(observed, predicted, s=25, alpha=0.8, color=point_color)


# 1:1 line
ax.plot([-2.5, 0], [-2.5, 0], linestyle="--", color="black")

# Axis formatting
ax.set_xlim(-2.5, 0)
ax.set_ylim(-2.5, 0)
ax.set_xlabel("ΔT gradient estimated by matching\nMEPDG and field performance (°F/in)")
ax.set_ylabel("Predicted ΔT gradient (°F/in)")

# Force x-axis label and ticks to bottom
ax.xaxis.set_label_position("bottom")
ax.tick_params(axis="x", bottom=True, labelbottom=True, top=False, labeltop=False)

# Manual grid lines
for y in np.arange(-2.5, 0.5, 0.5):
    ax.axhline(y=y, color="gray", linestyle="-", linewidth=0.7, alpha=0.5)

# Annotation
ax.text(-2.4, -0.4, "N = 147\nR² = 0.497\nRMSE = 0.320", fontsize=10)

# Aspect ratio
ax.set_aspect("equal", adjustable="box")

plt.savefig("figure4_delta_gradient.pdf", bbox_inches="tight")
plt.show()

# %%
# Correlation Plot 1: ChatGPT vs Original Delta Gradient
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

    -1.05752, -2.09566, -0.56056, -2.68859, -1.06629, -0.48862, -1.57221, -2.70791, -1.58411, -1.26393,
    -1.18976, -1.21384, -0.19396, -2.08855, -1.9453, -2.01823, -1.14166, -1.6093, -1.30592, -2.33471, -2.67275
]

# --- Matching pairs ---
x = np.array(original_y[:len(generated_y)])
y = np.array(generated_y)

# --- Correlation ---
r, p = pearsonr(x, y)

# --- Plot ---
sns.set_theme(style="whitegrid")
palette = sns.color_palette("mako")

fig, ax = plt.subplots(figsize=(6,6))

ax.scatter(x, y, color=palette[4], s=60, edgecolor="black", alpha=0.85)
ax.plot([min(x.min(), y.min()), max(x.max(), y.max())],
        [min(x.min(), y.min()), max(x.max(), y.max())],
        linestyle="--", color=palette[-1], linewidth=2.2, label="1:1 Line")

ax.set_xlabel("Original Data (Y)", fontsize=16, labelpad=10)
ax.set_ylabel("Generated Data (Y)", fontsize=16, labelpad=10)
ax.tick_params(axis="both", labelsize=14)

ax.text(0.02, 0.02, f"r = {r:.3f}\np = {p:.3g}\nN = {len(x)}",
        transform=ax.transAxes, fontsize=14, weight="semibold",
        ha="left", va="bottom")

ax.set_aspect("equal", adjustable="box")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = [
    "AC/800/60_3mm", "AC/800/60_7mm", "AC/800/240_3mm", "AC/800/240_7mm",
    "AC/1000/240_3mm", "AC/1000/240_7mm", "WC/800/60_3mm", "WC/800/60_7mm"
]
x = np.arange(len(labels))

ferrite = [2.5, 3.0, 3.5, 4.0, 3.8, 4.2, 1.8, 2.2]
pearlite = [5.0, 6.0, 10.0, 12.0, 11.0, 13.0, 3.5, 4.0]
hardness = [200, 220, 250, 240, 230, 260, 280, 300]
uts = [800, 810, 805, 820, 815, 825, 1000, 1050]

set_pub_style()
fig, ax1 = plt.subplots(figsize=(7,3.5))  # wider for bar labels

# Bar chart
width = 0.35
ax1.bar(x - width/2, ferrite, width, label="Ferrite")
ax1.bar(x + width/2, pearlite, width, label="Pearlite")

# Labels
ax1.set_ylabel("Equivalent Grain Diameter (µm)")
ax1.set_xticks(x)
ax1.set_xticklabels(labels, rotation=45, ha="right")

# Secondary y-axis
ax2 = ax1.twinx()
ax2.plot(x, uts, marker="d", linestyle="-", label="UTS (MPa)")
ax2.plot(x, hardness, marker="^", linestyle="-", label="Hardness (HV)")
ax2.set_ylim(0, 1200)
ax2.set_ylabel("UTS / Hardness")

# Combine legends in top-left
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(handles1 + handles2, labels1 + labels2,
           frameon=False, loc="upper left")

plt.savefig("figure_bar_grains.pdf", bbox_inches="tight")
plt.show()

# %%
#New Figure 4 Correlation
# Correlation Plot 2: Gemini Material Fatigue
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# --- Original Data ---
original_x = [
    780.1820767843761, 1085.634484087389, 1277.0152529764794, 1380.056573998483, 1701.7237706246092,
    2098.3659989521752, 2617.752219579204, 3265.696587980231, 4074.0197353208832, 5141.922721546919,
    6565.730960564977, 8070.997743592152, 8383.794424968048, 10705.283140946283, 14134.783745295976,
    15902.751291469871, 17865.8414418142, 23080.017503515814, 29815.95967351792, 49759.282491570884,
    64281.61330145693, 63643.4636599469, 84998.18811862222, 109805.05317558255, 141851.84378360756,
    183251.5444679333, 236733.8178635892, 239505.46248607445, 305824.98326543684, 316692.89724201075,
    395080.522222633, 510385.44128434936, 659342.2961211642, 843550.3189849987, 1100363.6955034493,
    1421506.7023383428, 2372325.2358748973, 3064692.370988884, 3959128.0262773996, 5114606.241342735,
    8535668.131526452, 11026817.321839377, 30711484.812362466, 39674683.63227058, 51253807.197466806
]

original_y = [
    484.7620018427815, 481.64917670425075, 483.3303959418063, 466.5797980835031, 453.7034331436582,
    441.08588960963937, 427.80835149076415, 415.13904367558007, 402.5926760281634, 389.89748607239676,
    377.60993983080607, 360.36614854007973, 365.3806284055263, 354.3462651590926, 347.1822483083837,
    356.64540595889787, 331.4985534610281, 320.8045235566709, 310.3751973628176, 290.78712278552956,
    279.66536529816767, 271.3729963608584, 272.04610008185404, 266.9885925582376, 257.75209971464386,
    250.7639217573411, 244.25221047894541, 272.78727047126495, 237.84638068475124, 272.78727047126495,
    231.440550890557, 225.45824703316907, 219.21123946527723, 210.28190096427926, 208.5701503030208,
    208.14662436621455, 208.14662436621455, 208.35838733461765, 208.72897252932313, 208.72897252932313,
    208.72897252932313, 208.72897252932313, 208.72897252932313, 208.72897252932313, 208.72897252932313
]

# --- Generated Data ---
generated_x = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000, 500000, 1000000, 2000000, 5000000, 10000000]
generated_y = [488, 488, 360, 360, 355, 275, 275, 270, 210, 210, 210, 210, 210]

# Match lengths
N = min(len(generated_x), len(original_x))
x = np.array(original_y[:N])
y = np.array(generated_y[:N])

# Correlation
r, p = pearsonr(x, y)

# --- Plot ---
sns.set_theme(style="whitegrid")
palette = sns.color_palette("mako")

fig, ax = plt.subplots(figsize=(6,6))

ax.scatter(x, y, color=palette[2], s=65, edgecolor="black", alpha=0.85)
ax.plot([min(x.min(), y.min()), max(x.max(), y.max())],
        [min(x.min(), y.min()), max(x.max(), y.max())],
        linestyle="--", color=palette[-1], linewidth=2.2, label="1:1 Line")

ax.set_xlabel("Original Stress Amplitude (MPa)", fontsize=16, labelpad=10)
ax.set_ylabel("Generated Stress Amplitude (MPa)", fontsize=16, labelpad=10)
ax.tick_params(axis="both", labelsize=14)

ax.text(0.02, 0.02, f"r = {r:.3f}\np = {p:.3g}\nN = {len(x)}",
        transform=ax.transAxes, fontsize=14, weight="semibold",
        ha="left", va="bottom")

ax.set_aspect("equal", adjustable="box")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

file_path = "power_data_perplexity_updated.xlsx"
df = pd.read_excel(file_path, sheet_name=None)

set_pub_style()
fig, ax = plt.subplots()

# Plot each line
for sheet_name, data in df.items():
    data = data.rename(columns={data.columns[0]: "X", data.columns[1]: "Y"})
    line_color = next(colors)
    ax.plot(
        data["X"], data["Y"],
        marker="o",
        linestyle="-",
        label=sheet_name,
        markerfacecolor="white",     # white fill
        markeredgecolor=line_color,  # colored edge
        markeredgewidth=2.0,         # thicker edge for visibility
        color=line_color,            # line color matches marker edge
        alpha=0.9                    # slight transparency for line if desired
    )

# Labels
ax.set_xlabel("Voltage (mV)")
ax.set_ylabel("Power (µW)")
ax.legend(frameon=False)

plt.savefig("figure5_multicolor_lines.pdf", bbox_inches="tight")
plt.show()
